# %%
"""
This program converts J-scheme USDB TBME to neutron-neutron (nn) M-scheme TBME  and print in terms qubit number.
The qubits are arranged as follows:

qubit     n     l    2*j        2*jz
_______________________________________________________
0         0     2     5         -5
1         0     2     5         +5      
2         0     2     5         -3             
3         0     2     5         +3        
4         0     2     5         -1            
5         0     2     5         +1           
6         1     0     1         -1        
7         1     0     1         +1              
8         0     2     3         -3           
9         0     2     3         +3            
10        0     2     3         -1            
11        0     2     3         +1     

For different 2*m it will print different sets of TBMEs.
For sd-shell, allowed 2*m values are: 0, +/-2, +/-4, +/-6, +/-8, +/-10

"""

from sympy.physics.quantum.cg import CG
import numpy as np

"""
2  2  2  2    0  1  -2.5598
2  2  2  2    1  0  -1.3796
2  2  2  2    2  1  -1.0007
2  2  2  2    3  0  -1.6651
2  2  2  2    4  1  -0.2069
2  2  2  2    5  0  -4.3205


"""
mm = input("Enter 2*m:")
m = int(mm)
j1 = 5; j2 = 5; j3 = 5; j4 = 5

#18O --> n = 2; 20O --> n = 4; 22O --> n = 6

n = 2
factor = (18/(16+n))**0.3
    
# <5/2 5/2 | V | 5/2 5/2>    
if j1 == 5 and j2 == 5 and j3 == 5 and j4 == 5:
    V = np.array([-2.5598, -1.3796, -1.0007, -1.6651, -0.2069, -4.3205 ])
    J = np.array([0, 1, 2, 3, 4, 5])
    T = np.array([1, 0, 1, 0, 1, 0])
    C = 2    
    #print("m-scheme tbme for <5/2 5/2 | V | 5/2 5/2>")
    
t = 1
t1 = 1; t2 = 1  #p --> tz = -1 (-1/2); n --> tz = 1 (1/2)
t3 = 1; t4 = 1  #p --> tz = -1 (-1/2); n --> tz = 1 (1/2)


for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    #print(mm)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3 
                        elif m1 == 5:
                            m11 = 1
                        
                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1
                        
                        #define qubit for m3
                        if m3 == -5:
                            m33 = 0
                        elif m3 == -3:
                            m33 = 2
                        elif m3 == -1:
                            m33 = 4
                        elif m3 == 1:
                            m33 = 5
                        elif m3 == 3:
                            m33 = 3
                        elif m3 == 5:
                            m33 = 1
                            
                        #define qubit for m4
                        if m4 == -5:
                            m44 = 0
                        elif m4 == -3:
                            m44 = 2
                        elif m4 == -1:
                            m44 = 4
                        elif m4 == 1:
                            m44 = 5
                        elif m4 == 3:
                            m44 = 3
                        elif m4 == 5:
                            m44 = 1    
                        #print(f"H += of.ops.FermionOperator({m11}^ {m22}^ {m44} {m33}, {float(tbme)}*f)")
                        print(m11, m22, m33, m44, float(tbme))

"""
2=d5/2;  3=s1/2

2  2  3  3    1  0  -0.5344
2  2  3  3    0  1  -1.5602

"""

j1 = 5; j2 = 5; j3 = 1; j4 = 1
    
# <5/2 5/2 | V | 1/2 1/2>    
if j1 == 5 and j2 == 5 and j3 == 1 and j4 == 1:
    V = np.array([-0.5344, -1.5602])
    J = np.array([1, 0])
    T = np.array([0, 1])
    C = 2    
    #print("m-scheme tbme for <5/2 5/2 | V | 1/2 1/2>")
    

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3 
                        elif m1 == 5:
                            m11 = 1
                        
                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1
                        
                        #define qubit for m3
                        if m3 == -1:
                            m33 = 6
                        elif m3 == 1:
                            m33 = 7
                        
                            
                        #define qubit for m4
                        if m4 == -1:
                            m44 = 6
                        elif m4 == 1:
                            m44 = 7  
                        print(m11, m22, m33, m44, float(tbme))

"""
2=d5/2;  3=s1/2

2  3  2  3    2  0  -0.3154
2  3  2  3    2  1  -0.9405
2  3  2  3    3  0  -4.1823
2  3  2  3    3  1   0.6841

"""

j1 = 5; j2 = 1; j3 = 5; j4 = 1
    
# <5/2 1/2 | V | 5/2 1/2>    
if j1 == 5 and j2 == 1 and j3 == 5 and j4 == 1:
    V = np.array([-0.3154, -0.9405, -4.1823, 0.6841])
    J = np.array([2, 2, 3, 3])
    T = np.array([0, 1, 0, 1])
    C = 1    
    #print("m-scheme tbme for <5/2 1/2 | V | 5/2 1/2>")
    

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                       
                    
                    #define qubit for m1
                    if m1 == -5:
                        m11 = 0
                    elif m1 == -3:
                        m11 = 2
                    elif m1 == -1:
                        m11 = 4
                    elif m1 == 1:
                        m11 = 5
                    elif m1 == 3:
                        m11 = 3 
                    elif m1 == 5:
                        m11 = 1
                        
                    #define qubit for m2
                    if m2 == -1:
                        m22 = 6
                    elif m2 == 1:
                        m22 = 7
                        
                        
                    #define qubit for m3
                    if m3 == -5:
                        m33 = 0
                    elif m3 == -3:
                        m33 = 2
                    elif m3 == -1:
                        m33 = 4
                    elif m3 == 1:
                        m33 = 5
                    elif m3 == 3:
                        m33 = 3
                    elif m3 == 5:
                        m33 = 1    
                            
                    #define qubit for m4
                    if m4 == -1:
                        m44 = 6
                    elif m4 == 1:
                        m44 = 7  
                    print(m11, m22, m33, m44, float(tbme))

"""
2=d5/2;  3=s1/2

3  3  3  3    0  1  -1.6913
3  3  3  3    1  0  -3.7093

"""

j1 = 1; j2 = 1; j3 = 1; j4 = 1
    
# <1/2 1/2 | V | 1/2 1/2>    
if j1 == 1 and j2 == 1 and j3 == 1 and j4 == 1:
    V = np.array([-1.6913, -3.7093])
    J = np.array([0, 1])
    T = np.array([1, 0])
    C = 2    
    #print("m-scheme tbme for <1/2 1/2 | V | 1/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -1:
                            m11 = 6
                        elif m1 == 1:
                            m11 = 7
                        
                        #define qubit for m2
                        if m2 == -1:
                            m22 = 6
                        elif m2 == 1:
                            m22 = 7
                        
                        
                        #define qubit for m3
                        if m3 == -1:
                            m33 = 6
                        elif m3 == 1:
                            m33 = 7
                        
                            
                        #define qubit for m4
                        if m4 == -1:
                            m44 = 6
                        elif m4 == 1:
                            m44 = 7  
                        print(m11, m22, m33, m44, float(tbme))

"""
 2  2  1  1    0  1  -3.1025
 2  2  1  1    1  0   1.6647
 2  2  1  1    2  1  -1.2187
 2  2  1  1    3  0   1.1792
"""
j1 = 5; j2 = 5; j3 = 3; j4 = 3



# <3/2 3/2 | V | 5/2 5/2>
if j1 == 5 and j2 == 5 and j3 == 3 and j4 == 3:
    V = np.array([-3.1025, 1.6647, -1.2187, 1.1792])
    J = np.array([0, 1, 2, 3])
    T = np.array([1, 0, 1, 0])
    C =  2
    #print("m-scheme tbme for <5/2 5/2 | V | 3/2 3/2>")

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:

                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()

                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])

                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3
                        elif m1 == 5:
                            m11 = 1

                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1

                        #define qubit for m3
                        #if m3 == -5:
                        #    m33 = 7
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9
                        #elif m3 == 5:
                        #    m33 = 12

                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))

"""
2  1  2  1    1  0  -6.0099
2  1  2  1    2  0  -4.2117
2  1  2  1    3  0  -1.2124
2  1  2  1    4  0  -4.6189
2  1  2  1    1  1   0.6556
2  1  2  1    2  1  -0.1545
2  1  2  1    3  1   0.7673
2  1  2  1    4  1  -1.4447

"""

j1 = 5; j2 = 3; j3 = 5; j4 = 3
    
# <5/2 3/2 | V | 5/2 3/2>    
if j1 == 5 and j2 == 3 and j3 == 5 and j4 == 3:
    V = np.array([-6.0099, -4.2117, -1.2124, -4.6189, 0.6556, -0.1545, 0.7673, -1.4447 ])
    J = np.array([1, 2, 3, 4, 1, 2, 3, 4 ])
    T = np.array([0, 0, 0, 0, 1, 1, 1, 1])
    C =  1 
    #print("m-scheme tbme for <5/2 3/2 | V | 5/2 3/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                       
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    #if m1 < m2 and m3 < m4:
                    #define qubit for m1
                    if m1 == -5:
                        m11 = 0
                    elif m1 == -3:
                        m11 = 2
                    elif m1 == -1:
                        m11 = 4
                    elif m1 == 1:
                        m11 = 5
                    elif m1 == 3:
                        m11 = 3
                    elif m1 == 5:
                        m11 = 1
                        
                    #define qubit for m2
                    if m2 == -3:
                        m22 = 8
                    elif m2 == -1:
                        m22 = 10
                    elif m2 == 1:
                        m22 = 11
                    elif m2 == 3:
                        m22 = 9
                        
                    #define qubit for m3
                    if m3 == -5:
                        m33 = 0
                    if m3 == -3:
                        m33 = 2
                    elif m3 == -1:
                        m33 = 4
                    elif m3 == 1:
                        m33 = 5
                    elif m3 == 3:
                        m33 = 3
                    elif m3 == 5:
                        m33 = 1        
                            
                    #define qubit for m4
                    if m4 == -3:
                        m44 = 8
                    elif m4 == -1:
                        m44 = 10
                    elif m4 == 1:
                        m44 = 11
                    elif m4 == 3:
                        m44 = 9
                    print(m11, m22, m33, m44, float(tbme))                     

"""
1=d3/2

1  1  1  1    0  1  -1.8992
1  1  1  1    1  0  -1.6582
1  1  1  1    2  1  -0.0974
1  1  1  1    3  0  -2.9660


"""

j1 = 3; j2 = 3; j3 = 3; j4 = 3
    
# <3/2 3/2 | V | 3/2 3/2>    
if j1 == 3 and j2 == 3 and j3 == 3 and j4 == 3:
    V = np.array([-1.8992, -1.6582, -0.0974, -2.9660])
    J = np.array([0, 1, 2, 3 ])
    T = np.array([1, 0, 1, 0])
    C = 2 
    #print("m-scheme tbme for <3/2 3/2 | V | 3/2 3/2>")
    

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                       
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -3:
                            m11 = 8
                        elif m1 == -1:
                            m11 = 10
                        elif m1 == 1:
                            m11 = 11
                        elif m1 == 3:
                            m11 = 9
                        
                        #define qubit for m2
                        if m2 == -3:
                            m22 = 8
                        elif m2 == -1:
                            m22 = 10
                        elif m2 == 1:
                            m22 = 11
                        elif m2 == 3:
                            m22 = 9
                        
                        #define qubit for m3
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9       
                            
                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))                        

"""
1=d3/2   3=1s1/2

1  1  3  3    0  1  -1.0150
1  1  3  3    1  0   0.1574

"""

j1 = 1; j2 = 1; j3 = 3; j4 = 3
    
# <3/2 3/2 | V | 1/2 1/2>    
if j1 == 1 and j2 == 1 and j3 == 3 and j4 == 3:
    V = np.array([-1.0150, 0.1574])
    J = np.array([ 0, 1])
    T = np.array([ 1, 0])
    C = 2 
    #print("m-scheme tbme for <3/2 3/2 | V | 1/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -1:
                            m11 = 6
                        elif m1 == 1:
                            m11 = 7
                        
                        #define qubit for m2
                        if m2 == -1:
                            m22 = 6
                        elif m2 == 1:
                            m22 = 7
                        
                        
                        #define qubit for m3
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9       
                            
                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))                     

"""
1=d3/2   3=1s1/2

1  3  1  3    1  0  -4.0460
1  3  1  3    1  1   0.5158
1  3  1  3    2  0  -1.8504
1  3  1  3    2  1  -0.3034

"""

j1 = 1; j2 = 3; j3 = 1; j4 = 3
    
# <3/2 1/2 | V | 3/2 1/2>    
if j1 == 1 and j2 == 3 and j3 == 1 and j4 == 3:
    V = np.array([-4.0460, 0.5158, -1.8504, -0.3034])
    J = np.array([ 1, 1, 2, 2])
    T = np.array([ 0, 1, 0, 1])
    C = 1 
    #print("m-scheme tbme for <3/2 1/2 | V | 3/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    
                    #define qubit for m1
                    if m1 == -1:
                        m11 = 6
                    elif m1 == 1:
                        m11 = 7
                        
                    #define qubit for m2
                    if m2 == -3:
                        m22 = 8
                    elif m2 == -1:
                        m22 = 10
                    elif m2 == 1:
                        m22 = 11
                    elif m2 == 3:
                        m22 = 9
                    
                    #define qubit for m3
                    if m3 == -1:
                        m33 = 6
                    elif m3 == 1:
                        m33 = 7     
                            
                    #define qubit for m4
                    if m4 == -3:
                        m44 = 8
                    elif m4 == -1:
                        m44 = 10
                    elif m4 == 1:
                        m44 = 11
                    elif m4 == 3:
                        m44 = 9
                    print(m11, m22, m33, m44, float(tbme))
# Out:
# Enter 2*m:0
# 0 1 0 1 -1.4637
# 0 1 2 3 0.6898
# 0 1 4 5 -0.40630000000000005
# 2 3 0 1 0.6898
# 2 3 2 3 -1.0101
# 2 3 4 5 0.8599
# 4 5 0 1 -0.40630000000000005
# 4 5 2 3 0.8599
# 4 5 4 5 -1.2935999999999999
# 0 1 6 7 -0.9007818899896541
# 2 3 6 7 0.9007818899896541
# 4 5 6 7 -0.9007818899896541
# 4 7 4 7 -0.12819999999999998
# 4 7 5 6 0.8123
# 5 6 4 7 0.8123
# 5 6 5 6 -0.12819999999999998
# 6 7 6 7 -1.6913
# 0 1 8 9 -1.9314456782406446
# 0 1 10 11 0.6017349640876253
# 2 3 8 9 1.133619249748833
# 2 3 10 11 -1.399561392579437
# 4 5 8 9 -0.7347060355029272
# 4 5 10 11 1.7984746068253428
# 2 9 2 9 0.1919028571428571
# 2 9 4 11 -0.19837717572588742
# 2 9 5 10 -0.25309877657966345
# 2 9 3 8 -0.5307171428571429
# 4 11 2 9 -0.19837717572588742
# 4 11 4 11 -0.28005285714285716
# 4 11 5 10 -0.9803328571428571
# 4 11 3 8 -0.25309877657966345
# 5 10 2 9 -0.25309877657966345
# 5 10 4 11 -0.9803328571428571
# 5 10 5 10 -0.28005285714285716
# 5 10 3 8 -0.19837717572588742
# ...
