# %%
"""
This program converts J-scheme USDB TBME to neutron-neutron (nn) M-scheme TBME  and print in terms qubit number.
The qubits are arranged as follows:

qubit     n     l    2*j        2*jz
_______________________________________________________
0         0     2     5         -5
1         0     2     5         +5      
2         0     2     5         -3             
3         0     2     5         +3        
4         0     2     5         -1            
5         0     2     5         +1           
6         1     0     1         -1        
7         1     0     1         +1              
8         0     2     3         -3           
9         0     2     3         +3            
10        0     2     3         -1            
11        0     2     3         +1     

For different 2*m it will print different sets of TBMEs.
For sd-shell, allowed 2*m values are: 0, +/-2, +/-4, +/-6, +/-8, +/-10

"""

from sympy.physics.quantum.cg import CG
import numpy as np

mm = input("Enter 2*m:")
m = int(mm)
j1 = 5; j2 = 5; j3 = 5; j4 = 5

#18O --> n = 2
n = 2
factor = (18/(16+n))**0.0
t = 1
t1 = 1; t2 = 1  #p --> tz = -1 (-1/2); n --> tz = 1 (1/2)
t3 = 1; t4 = 1  #p --> tz = -1 (-1/2); n --> tz = 1 (1/2)


"""
2  2  2  2    0  1  -2.2780
2  2  2  2    1  0  -1.0110
2  2  2  2    2  1  -1.2560
2  2  2  2    3  0  -0.9490
2  2  2  2    4  1  -0.3700
2  2  2  2    5  0  -3.7240


"""

# <5/2 5/2 | V | 5/2 5/2>    
if j1 == 5 and j2 == 5 and j3 == 5 and j4 == 5:
    V = np.array([-2.2780, -1.0110, -1.2560, -0.9490, -0.3700, -3.7240])
    J = np.array([0, 1, 2, 3, 4, 5])
    T = np.array([1, 0, 1, 0, 1, 0])
    C = 2    
    #print("m-scheme tbme for <5/2 5/2 | V | 5/2 5/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    #print(mm)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3 
                        elif m1 == 5:
                            m11 = 1
                        
                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1
                        
                        #define qubit for m3
                        if m3 == -5:
                            m33 = 0
                        elif m3 == -3:
                            m33 = 2
                        elif m3 == -1:
                            m33 = 4
                        elif m3 == 1:
                            m33 = 5
                        elif m3 == 3:
                            m33 = 3
                        elif m3 == 5:
                            m33 = 1
                            
                        #define qubit for m4
                        if m4 == -5:
                            m44 = 0
                        elif m4 == -3:
                            m44 = 2
                        elif m4 == -1:
                            m44 = 4
                        elif m4 == 1:
                            m44 = 5
                        elif m4 == 3:
                            m44 = 3
                        elif m4 == 5:
                            m44 = 1    
                        print(m11, m22, m33, m44, float(tbme))

"""
2=d5/2;  3=s1/2

2  2  3  3    1  0  -0.7500
2  2  3  3    0  1  -1.2680

"""

j1 = 5; j2 = 5; j3 = 1; j4 = 1
    
# <5/2 5/2 | V | 1/2 1/2>    
if j1 == 5 and j2 == 5 and j3 == 1 and j4 == 1:
    V = np.array([-0.7500, -1.2680])
    J = np.array([1, 0])
    T = np.array([0, 1])
    C = 2    
    #print("m-scheme tbme for <5/2 5/2 | V | 1/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3 
                        elif m1 == 5:
                            m11 = 1
                        
                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1
                        
                        #define qubit for m3
                        if m3 == -1:
                            m33 = 6
                        elif m3 == 1:
                            m33 = 7
                        
                            
                        #define qubit for m4
                        if m4 == -1:
                            m44 = 6
                        elif m4 == 1:
                            m44 = 7  
                        print(m11, m22, m33, m44, float(tbme))

"""
2=d5/2;  3=s1/2

2  3  2  3    2  0  -0.5010
2  3  2  3    2  1  -1.4350
2  3  2  3    3  0  -3.7990
2  3  2  3    3  1  -0.0030


"""

j1 = 5; j2 = 1; j3 = 5; j4 = 1
    
# <5/2 1/2 | V | 5/2 1/2>    
if j1 == 5 and j2 == 1 and j3 == 5 and j4 == 1:
    V = np.array([-0.5010, -1.4350, -3.7990, -0.0030])
    J = np.array([2, 2, 3, 3])
    T = np.array([0, 1, 0, 1])
    C = 1    
    #print("m-scheme tbme for <5/2 1/2 | V | 5/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                       
                    
                    #define qubit for m1
                    if m1 == -5:
                        m11 = 0
                    elif m1 == -3:
                        m11 = 2
                    elif m1 == -1:
                        m11 = 4
                    elif m1 == 1:
                        m11 = 5
                    elif m1 == 3:
                        m11 = 3 
                    elif m1 == 5:
                        m11 = 1
                        
                    #define qubit for m2
                    if m2 == -1:
                        m22 = 6
                    elif m2 == 1:
                        m22 = 7
                        
                        
                    #define qubit for m3
                    if m3 == -5:
                        m33 = 0
                    elif m3 == -3:
                        m33 = 2
                    elif m3 == -1:
                        m33 = 4
                    elif m3 == 1:
                        m33 = 5
                    elif m3 == 3:
                        m33 = 3
                    elif m3 == 5:
                        m33 = 1    
                            
                    #define qubit for m4
                    if m4 == -1:
                        m44 = 6
                    elif m4 == 1:
                        m44 = 7  
                    print(m11, m22, m33, m44, float(tbme))

"""
2=d5/2;  3=s1/2

3  3  3  3    0  1  -2.1060
3  3  3  3    1  0  -3.0890

"""

j1 = 1; j2 = 1; j3 = 1; j4 = 1
    
# <1/2 1/2 | V | 1/2 1/2>    
if j1 == 1 and j2 == 1 and j3 == 1 and j4 == 1:
    V = np.array([-2.1060, -3.0890])
    J = np.array([0, 1])
    T = np.array([1, 0])
    C = 2    
    #print("m-scheme tbme for <1/2 1/2 | V | 1/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -1:
                            m11 = 6
                        elif m1 == 1:
                            m11 = 7
                        
                        #define qubit for m2
                        if m2 == -1:
                            m22 = 6
                        elif m2 == 1:
                            m22 = 7
                        
                        
                        #define qubit for m3
                        if m3 == -1:
                            m33 = 6
                        elif m3 == 1:
                            m33 = 7
                        
                            
                        #define qubit for m4
                        if m4 == -1:
                            m44 = 6
                        elif m4 == 1:
                            m44 = 7  
                        print(m11, m22, m33, m44, float(tbme))

"""
 2  2  1  1    0  1  -3.5380
 2  2  1  1    1  0   2.2650
 2  2  1  1    2  1  -0.8130
 2  2  1  1    3  0   0.5620
"""
j1 = 5; j2 = 5; j3 = 3; j4 = 3



# <3/2 3/2 | V | 5/2 5/2>
if j1 == 5 and j2 == 5 and j3 == 3 and j4 == 3:
    V = np.array([-3.5380, 2.2650, -0.8130, 0.5620])
    J = np.array([0, 1, 2, 3])
    T = np.array([1, 0, 1, 0])
    C =  2
    #print("m-scheme tbme for <5/2 5/2 | V | 3/2 3/2>")

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:

                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()

                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])

                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3
                        elif m1 == 5:
                            m11 = 1

                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1

                        #define qubit for m3
                        #if m3 == -5:
                        #    m33 = 7
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9
                        #elif m3 == 5:
                        #    m33 = 12

                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))

"""
2  1  2  1    1  0  -5.6180
2  1  2  1    2  0  -4.3350
2  1  2  1    3  0  -1.0870
2  1  2  1    4  0  -4.5400
2  1  2  1    1  1  -0.3390
2  1  2  1    2  1  -0.4140
2  1  2  1    3  1  -0.1510
2  1  2  1    4  1  -1.9950

"""

j1 = 5; j2 = 3; j3 = 5; j4 = 3
    
# <5/2 3/2 | V | 5/2 3/2>    
if j1 == 5 and j2 == 3 and j3 == 5 and j4 == 3:
    V = np.array([-5.6180, -4.3350, -1.0870, -4.5400, -0.3390, -0.4140, -0.1510, -1.9950 ])
    J = np.array([1, 2, 3, 4, 1, 2, 3, 4 ])
    T = np.array([0, 0, 0, 0, 1, 1, 1, 1])
    C =  1 
    #print("m-scheme tbme for <5/2 3/2 | V | 5/2 3/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                       
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    #if m1 < m2 and m3 < m4:
                    #define qubit for m1
                    if m1 == -5:
                        m11 = 0
                    elif m1 == -3:
                        m11 = 2
                    elif m1 == -1:
                        m11 = 4
                    elif m1 == 1:
                        m11 = 5
                    elif m1 == 3:
                        m11 = 3
                    elif m1 == 5:
                        m11 = 1
                        
                    #define qubit for m2
                    if m2 == -3:
                        m22 = 8
                    elif m2 == -1:
                        m22 = 10
                    elif m2 == 1:
                        m22 = 11
                    elif m2 == 3:
                        m22 = 9
                        
                    #define qubit for m3
                    if m3 == -5:
                        m33 = 0
                    if m3 == -3:
                        m33 = 2
                    elif m3 == -1:
                        m33 = 4
                    elif m3 == 1:
                        m33 = 5
                    elif m3 == 3:
                        m33 = 3
                    elif m3 == 5:
                        m33 = 1        
                            
                    #define qubit for m4
                    if m4 == -3:
                        m44 = 8
                    elif m4 == -1:
                        m44 = 10
                    elif m4 == 1:
                        m44 = 11
                    elif m4 == 3:
                        m44 = 9
                    print(m11, m22, m33, m44, float(tbme))                        

"""
1=d3/2

1  1  1  1    0  1  -0.8580
1  1  1  1    1  0  -0.8740
1  1  1  1    2  1  -0.2590
1  1  1  1    3  0  -2.5960


"""

j1 = 3; j2 = 3; j3 = 3; j4 = 3
    
# <3/2 3/2 | V | 3/2 3/2>    
if j1 == 3 and j2 == 3 and j3 == 3 and j4 == 3:
    V = np.array([-0.8580, -0.8740, -0.2590, -2.5960])
    J = np.array([0, 1, 2, 3 ])
    T = np.array([1, 0, 1, 0])
    C = 2 
    #print("m-scheme tbme for <3/2 3/2 | V | 3/2 3/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                       
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -3:
                            m11 = 8
                        elif m1 == -1:
                            m11 = 10
                        elif m1 == 1:
                            m11 = 11
                        elif m1 == 3:
                            m11 = 9
                        
                        #define qubit for m2
                        if m2 == -3:
                            m22 = 8
                        elif m2 == -1:
                            m22 = 10
                        elif m2 == 1:
                            m22 = 11
                        elif m2 == 3:
                            m22 = 9
                        
                        #define qubit for m3
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9       
                            
                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))                        

"""
1=d3/2   3=1s1/2

1  1  3  3    0  1  -0.9910
1  1  3  3    1  0  -0.1750

"""

j1 = 1; j2 = 1; j3 = 3; j4 = 3
    
# <3/2 3/2 | V | 1/2 1/2>    
if j1 == 1 and j2 == 1 and j3 == 3 and j4 == 3:
    V = np.array([-0.9910, -0.1750])
    J = np.array([ 0, 1])
    T = np.array([ 1, 0])
    C = 2 
    #print("m-scheme tbme for <3/2 3/2 | V | 1/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -1:
                            m11 = 6
                        elif m1 == 1:
                            m11 = 7
                        
                        #define qubit for m2
                        if m2 == -1:
                            m22 = 6
                        elif m2 == 1:
                            m22 = 7
                        
                        
                        #define qubit for m3
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9       
                            
                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))                        

"""
1=d3/2   3=1s1/2

1  3  1  3    1  0  -3.8680
1  3  1  3    1  1  -0.0780
1  3  1  3    2  0  -1.5740
1  3  1  3    2  1  -0.6630

"""

j1 = 1; j2 = 3; j3 = 1; j4 = 3
    
# <3/2 1/2 | V | 3/2 1/2>    
if j1 == 1 and j2 == 3 and j3 == 1 and j4 == 3:
    V = np.array([-3.8680, -0.0780, -1.5740, -0.6630])
    J = np.array([ 1, 1, 2, 2])
    T = np.array([ 0, 1, 0, 1])
    C = 1 
    #print("m-scheme tbme for <3/2 1/2 | V | 3/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    
                    #define qubit for m1
                    if m1 == -1:
                        m11 = 6
                    elif m1 == 1:
                        m11 = 7
                        
                    #define qubit for m2
                    if m2 == -3:
                        m22 = 8
                    elif m2 == -1:
                        m22 = 10
                    elif m2 == 1:
                        m22 = 11
                    elif m2 == 3:
                        m22 = 9
                    
                    #define qubit for m3
                    if m3 == -1:
                        m33 = 6
                    elif m3 == 1:
                        m33 = 7     
                            
                    #define qubit for m4
                    if m4 == -3:
                        m44 = 8
                    elif m4 == -1:
                        m44 = 10
                    elif m4 == 1:
                        m44 = 11
                    elif m4 == 3:
                        m44 = 9
                    print(m11, m22, m33, m44, float(tbme))
# Out:
# Enter 2*m:0
# 0 1 0 1 -1.5333809523809523
# 0 1 2 3 0.5305238095238095
# 0 1 4 5 -0.21409523809523814
# 2 3 0 1 0.5305238095238095
# 2 3 2 3 -1.027095238095238
# 2 3 4 5 0.7203809523809523
# 4 5 0 1 -0.21409523809523814
# 4 5 2 3 0.7203809523809523
# 4 5 4 5 -1.3435238095238093
# 0 1 6 7 -0.7320801413324454
# 2 3 6 7 0.7320801413324454
# 4 5 6 7 -0.7320801413324454
# 4 7 4 7 -0.719
# 4 7 5 6 0.7160000000000001
# 5 6 4 7 0.7160000000000001
# 5 6 5 6 -0.719
# 6 7 6 7 -2.106
# 0 1 8 9 -1.8879103135658015
# 0 1 10 11 1.0008545897564927
# 2 3 8 9 1.3556768792802163
# 2 3 10 11 -1.533088024042078
# 4 5 8 9 -1.0895601621374236
# 4 5 10 11 1.7992047411848706
# 2 9 2 9 -0.43302857142857143
# 2 9 4 11 -0.23056697021711942
# 2 9 5 10 -0.3226677845457669
# 2 9 3 8 -0.2068285714285714
# 4 11 2 9 -0.23056697021711942
# 4 11 4 11 -1.0164714285714287
# 4 11 5 10 -0.7526714285714285
# 4 11 3 8 -0.3226677845457669
# 5 10 2 9 -0.3226677845457669
# 5 10 4 11 -0.7526714285714285
# 5 10 5 10 -1.0164714285714287
# 5 10 3 8 -0.23056697021711942
# 3 8 2 9 -0.2068285714285714
# 3 8 4 11 -0.3226677845457669
# 3 8 5 10 -0.23056697021711942
# 3 8 3 8 -0.43302857142857143
# 8 9 8 9 -0.5585
# 8 9 10 11 0.2995
# 10 11 8 9 0.2995
# 10 11 10 11 -0.5585
# 6 7 8 9 -0.7007428201558686
# 6 7 10 11 0.7007428201558686
# 6 11 6 11 -0.3705
# 6 11 7 10 -0.29250000000000004
# 7 10 6 11 -0.29250000000000004
# 7 10 7 10 -0.3705
