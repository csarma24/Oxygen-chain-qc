# %%
#USDB


import pennylane as qml
from pennylane import numpy as np
import openfermion as of
import matplotlib.pyplot as plt
from openfermion.utils import hermitian_conjugated
import time
start_time = time.time()

s1 = -3.2079
s3 =  2.1117
s5 = -3.9257

# One-body terms
H  = of.ops.FermionOperator("0^ 0", s5)
H += of.ops.FermionOperator("1^ 1", s5)
H += of.ops.FermionOperator("2^ 2", s5)
H += of.ops.FermionOperator("3^ 3", s5)
H += of.ops.FermionOperator("4^ 4", s5)
H += of.ops.FermionOperator("5^ 5", s5)
H += of.ops.FermionOperator("6^ 6", s1)
H += of.ops.FermionOperator("7^ 7", s1)
H += of.ops.FermionOperator("8^ 8", s3)
H += of.ops.FermionOperator("9^ 9", s3)
H += of.ops.FermionOperator("10^ 10", s3)
H += of.ops.FermionOperator("11^ 11", s3)

#Two-body terms

#Diagonal
H += of.ops.FermionOperator("1^ 4^ 4 1", -0.49039)
H += of.ops.FermionOperator("1^ 6^ 6 1", -0.66973)
H += of.ops.FermionOperator("1^ 10^ 10 1", 0.09135)

H += of.ops.FermionOperator("3^ 5^ 5 3", -0.7172)
H += of.ops.FermionOperator("3^ 7^ 7 3", 0.41333)
H += of.ops.FermionOperator("3^ 11^ 11 3", -0.76886)

H += of.ops.FermionOperator("5^ 9^ 9 5", -0.15439)

H += of.ops.FermionOperator("7^ 9^ 9 7", -0.3034)

H += of.ops.FermionOperator("9^ 11^ 11 9",-0.0974)


#Off-diagonal
#H += of.ops.FermionOperator("^ ^ ", )

H += of.ops.FermionOperator("1^ 4^ 6 1", -0.50828)
H += of.ops.FermionOperator("1^ 6^ 4 1", -0.50828)
H += of.ops.FermionOperator("1^ 4^ 10 1", -0.4385)
H += of.ops.FermionOperator("1^ 10^ 4 1", -0.4385)
H += of.ops.FermionOperator("1^ 4^ 5 3", 0.3804)
H += of.ops.FermionOperator("3^ 5^ 4 1", 0.3804)
H += of.ops.FermionOperator("1^ 4^ 7 3", 0.2273)
H += of.ops.FermionOperator("3^ 7^ 4 1", 0.2273)
H += of.ops.FermionOperator("1^ 4^ 11 3", -0.70456)
H += of.ops.FermionOperator("3^ 11^ 4 1", -0.70456)
H += of.ops.FermionOperator("1^ 4^ 9 5", -0.6879)
H += of.ops.FermionOperator("5^ 9^ 4 1", -0.6879)
H += of.ops.FermionOperator("1^ 4^ 9 7", -0.52984)
H += of.ops.FermionOperator("7^ 9^ 4 1", -0.52984)
H += of.ops.FermionOperator("1^ 4^ 11 9",-0.7283)
H += of.ops.FermionOperator("9^ 11^ 4 1",-0.7283)

H += of.ops.FermionOperator("1^ 6^ 10 1", -0.34384)
H += of.ops.FermionOperator("1^ 10^ 6 1", -0.34384)
H += of.ops.FermionOperator("1^ 6^ 5 3", 0.6819)
H += of.ops.FermionOperator("3^ 5^ 6 1", 0.6819)
H += of.ops.FermionOperator("1^ 6^ 7 3", 0.6054)
H += of.ops.FermionOperator("3^ 7^ 6 1", 0.6054)
H += of.ops.FermionOperator("1^ 6^ 11 3", 0.1122)
H += of.ops.FermionOperator("3^ 11^ 6 1 ", 0.1122)
H += of.ops.FermionOperator("1^ 6^ 9 5", 0.05091)
H += of.ops.FermionOperator("5^ 9^ 6 1", 0.05091)
H += of.ops.FermionOperator("1^ 6^ 9 7 ", -1.47255)
H += of.ops.FermionOperator("7^ 9^ 6 1 ", -1.47255)
H += of.ops.FermionOperator("1^ 6^ 11 9", -0.28965 )
H += of.ops.FermionOperator("9^ 11^ 6 1", -0.28965)

H += of.ops.FermionOperator("1^ 10^ 5 3", -0.14289)
H += of.ops.FermionOperator("3^ 5^ 10 1", -0.14289)
H += of.ops.FermionOperator("1^ 10^ 7 3", -0.2369)
H += of.ops.FermionOperator("3^ 7^ 10 1 ", -0.2369)
H += of.ops.FermionOperator("1^ 10^ 11 3 ", -0.1373)
H += of.ops.FermionOperator("3^ 11^ 10 1", -0.1373)
H += of.ops.FermionOperator("1^ 10^ 9 5", -0.6731)
H += of.ops.FermionOperator("5^ 9^ 10 1 ", -0.6731)
H += of.ops.FermionOperator("1^ 10^ 9 7", -0.25622)
H += of.ops.FermionOperator("7^ 9^ 10 1 ", -0.25622)
H += of.ops.FermionOperator("1^ 10^ 11 9", -0.3472)
H += of.ops.FermionOperator("9^ 11^ 10 1", -0.3472)

H += of.ops.FermionOperator("3^ 5^ 7 3", -0.30497)
H += of.ops.FermionOperator("3^ 7^ 5 3 ", -0.30497)
H += of.ops.FermionOperator("3^ 5^ 11 3", -0.68965)
H += of.ops.FermionOperator("3^ 11^ 5 3 ", -0.68965)
H += of.ops.FermionOperator("3^ 5^ 9 5 ", -0.41199)
H += of.ops.FermionOperator("5^ 9^ 5 3 ", -0.41199)
H += of.ops.FermionOperator("3^ 5^ 9 7", 0.71086)
H += of.ops.FermionOperator("7^ 9^ 5 3", 0.71086)
H += of.ops.FermionOperator("3^ 5^ 11 9", 0.97713)
H += of.ops.FermionOperator("9^ 11^ 5 3", 0.97713)

H += of.ops.FermionOperator("3^ 7^ 11 3", -0.22489)
H += of.ops.FermionOperator("3^ 11^ 7 3", -0.22489)
H += of.ops.FermionOperator("3^ 7^ 9 5", 0.4052)
H += of.ops.FermionOperator("5^ 9^ 7 3", 0.4052)
H += of.ops.FermionOperator("3^ 7^ 9 7", 0.65855)
H += of.ops.FermionOperator("7^ 9^ 7 3", 0.65855)
H += of.ops.FermionOperator("3^ 7^ 11 9", 0.12954)
H += of.ops.FermionOperator("9^ 11^ 7 3", 0.12954)

H += of.ops.FermionOperator("3^ 11^ 9 5", -0.7525 )
H += of.ops.FermionOperator("5^ 9^ 11 3 ", -0.7525)
H += of.ops.FermionOperator("3^ 11^ 9 7", 0.22917)
H += of.ops.FermionOperator("7^ 9^ 11 3", 0.22917)
H += of.ops.FermionOperator("3^ 11^ 11 9", 0.31058)
H += of.ops.FermionOperator("9^ 11^ 11 3 ", 0.31058)

H += of.ops.FermionOperator("5^ 9^ 9 7", -0.14034)
H += of.ops.FermionOperator("7^ 9^ 9 5", -0.14034)
H += of.ops.FermionOperator("5^ 9^ 11 9", -0.19019)
H += of.ops.FermionOperator("9^ 11^ 9 5", -0.19019)

H += of.ops.FermionOperator("7^ 9^ 11 9", -0.3494)
H += of.ops.FermionOperator("9^ 11^ 9 7 ", -0.3494)


exact_gs_energy = of.linalg.eigenspectrum(H)
H_JW = qml.import_operator(of.transforms.jordan_wigner(H), format="openfermion")
dev = qml.device("default.qubit", wires=12)

@qml.qnode(dev)
def excitation_ansatz1(params):
    # Prepare the Hartree-Fock state
    qml.PauliX(wires=1)
    qml.PauliX(wires=4)
    
    # SingleExcitation:   |1, 4> --> |1, 6>; |1, 10>
    qml.SingleExcitation(params[0], wires=[4, 6])
    qml.SingleExcitation(params[1], wires=[4, 10])
    
    # DoubleExcitation: |1, 4> --> |3, 5>; |3, 7>; |3, 11>, |5, 9>, |7, 9>, |9, 11>
    qml.DoubleExcitation(params[2], wires=[1, 4, 3, 5])
    qml.DoubleExcitation(params[3], wires=[1, 4, 7, 9])
    qml.DoubleExcitation(params[4], wires=[1, 4, 9, 11])
    qml.DoubleExcitation(params[5], wires=[1, 4, 3, 7])
    qml.DoubleExcitation(params[6], wires=[1, 4, 3, 11])
    qml.DoubleExcitation(params[7], wires=[1, 4, 5, 9])
    return qml.expval(H_JW)
    

    
N_its = 300
opt_exc1 = qml.GradientDescentOptimizer(stepsize=0.1)
energies_exc1 = []
params_exc1 = np.zeros(8)



for it in range(N_its):
    params_exc1, _cost = opt_exc1.step_and_cost(excitation_ansatz1, params_exc1)
    energies_exc1.append(_cost)
#print(params_exc1)


plt.rcParams["font.size"] = 14
plt.figure(figsize=(10, 6))
plt.plot(energies_exc1, label="Exc. Ansatz 1")
plt.axhline(y=-9.933, color="black", linestyle="dashed", label="Exact value")
plt.xlabel("Gradient descent iterations")
plt.ylabel("Energy")
plt.legend()
plt.show()

print(f"Energy from excitation ansatz1 = {energies_exc1[-1]}")  
print(f"Energy difference for ansatz1 = {abs(-9.933-energies_exc1[-1])}")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Energy from excitation ansatz1 = -9.933325657931556
# Energy difference for ansatz1 = 0.0003256579315564778
# --- 234.1533715724945 seconds ---

# %%
#DJ16


import pennylane as qml
from pennylane import numpy as np
import openfermion as of
import matplotlib.pyplot as plt
from openfermion.utils import hermitian_conjugated
import time
start_time = time.time()

s1 = -3.576
s3 =  6.675
s5 = -3.302

# One-body terms
H  = of.ops.FermionOperator("0^ 0", s5)
H += of.ops.FermionOperator("1^ 1", s5)
H += of.ops.FermionOperator("2^ 2", s5)
H += of.ops.FermionOperator("3^ 3", s5)
H += of.ops.FermionOperator("4^ 4", s5)
H += of.ops.FermionOperator("5^ 5", s5)
H += of.ops.FermionOperator("6^ 6", s1)
H += of.ops.FermionOperator("7^ 7", s1)
H += of.ops.FermionOperator("8^ 8", s3)
H += of.ops.FermionOperator("9^ 9", s3)
H += of.ops.FermionOperator("10^ 10", s3)
H += of.ops.FermionOperator("11^ 11", s3)

#Two-body terms

#Diagonal
H += of.ops.FermionOperator("1^ 4^ 4 1", -0.56607)
H += of.ops.FermionOperator("1^ 6^ 6 1", -1.07783)
H += of.ops.FermionOperator("1^ 10^ 10 1", -0.17683)

H += of.ops.FermionOperator("3^ 5^ 5 3", -0.83093)
H += of.ops.FermionOperator("3^ 7^ 7 3", 0.11083)
H += of.ops.FermionOperator("3^ 11^ 11 3", -0.91817)

H += of.ops.FermionOperator("5^ 9^ 9 5", -0.52900)

H += of.ops.FermionOperator("7^ 9^ 9 7", -0.518)

H += of.ops.FermionOperator("9^ 11^ 11 9",-0.225)


#Off-diagonal
#H += of.ops.FermionOperator("^ ^ ", )

H += of.ops.FermionOperator("1^ 4^ 6 1", -0.30060)
H += of.ops.FermionOperator("1^ 6^ 4 1", -0.30060)
H += of.ops.FermionOperator("1^ 4^ 10 1", -0.46385)
H += of.ops.FermionOperator("1^ 10^ 4 1", -0.46385)

H += of.ops.FermionOperator("1^ 4^ 5 3", 0.44417)
H += of.ops.FermionOperator("3^ 5^ 4 1", 0.44417)
H += of.ops.FermionOperator("1^ 4^ 7 3", 0.13443)
H += of.ops.FermionOperator("3^ 7^ 4 1", 0.13443)
H += of.ops.FermionOperator("1^ 4^ 11 3", -0.71316)
H += of.ops.FermionOperator("3^ 11^ 4 1", -0.71316)
H += of.ops.FermionOperator("1^ 4^ 9 5", -0.71458)
H += of.ops.FermionOperator("5^ 9^ 4 1", -0.71458)
H += of.ops.FermionOperator("1^ 4^ 9 7", -0.70339)
H += of.ops.FermionOperator("7^ 9^ 4 1", -0.70339)
H += of.ops.FermionOperator("1^ 4^ 11 9",-0.46076)
H += of.ops.FermionOperator("9^ 11^ 4 1",-0.46076)

H += of.ops.FermionOperator("1^ 6^ 10 1", -0.31571)
H += of.ops.FermionOperator("1^ 10^ 6 1", -0.31571)
H += of.ops.FermionOperator("1^ 6^ 5 3", 0.40329)
H += of.ops.FermionOperator("3^ 5^ 6 1", 0.40329)
H += of.ops.FermionOperator("1^ 6^ 7 3", 0.66448)
H += of.ops.FermionOperator("3^ 7^ 6 1", 0.66448)
H += of.ops.FermionOperator("1^ 6^ 11 3", 0.17490)
H += of.ops.FermionOperator("3^ 11^ 6 1 ", 0.17490)
H += of.ops.FermionOperator("1^ 6^ 9 5", -0.04128)
H += of.ops.FermionOperator("5^ 9^ 6 1", -0.04128)
params):
    # Prepare the Hartree-Fock state
    qml.PauliX(wires=1)
    qml.PauliX(wires=4)
    
    # SingleExcitation:   |1, 4> --> |1, 6>; |1, 10>
    qml.SingleExcitation(params[0], wires=[4, 6])
    qml.SingleExcitation(params[1], wires=[4, 10])
    
    # DoubleExcitation: |1, 4> --> |3, 5>; |3, 7>; |3, 11>, |5, 9>, |7, 9>, |9, 11>
    qml.DoubleExcitation(params[2], wires=[1, 4, 3, 5])
    qml.DoubleExcitation(params[3], wires=[1, 4, 7, 9])
    qml.DoubleExcitation(params[4], wires=[1, 4, 9, 11])
    qml.DoubleExcitation(params[5], wires=[1, 4, 3, 7])
    qml.DoubleExcitation(params[6], wires=[1, 4, 3, 11])
    qml.DoubleExcitation(params[7], wires=[1, 4, 5, 9])
    return qml.expval(H_JW)
    

    
N_its = 300
opt_exc1 = qml.GradientDescentOptimizer(stepsize=0.1)
energies_exc1 = []
params_exc1 = np.zeros(8)



for it in range(N_its):
    params_exc1, _cost = opt_exc1.step_and_cost(excitation_ansatz1, params_exc1)
    energies_exc1.append(_cost)
#print(params_exc1)


plt.axhline(y=-9.009, color="black", linestyle="dashed", label="Exact value")
plt.xlabel("Gradient descent iterations")
plt.ylabel("Energy")
plt.text(70, -7.4, r'DJ16')
plt.text(70, -7.2, r'$^{18}$O (2$^+$)')
plt.legend()
plt.show()

print(f"Energy from excitation ansatz1 = {energies_exc1[-1]}")  
print(f"Energy difference for ansatz1 = {abs(-9.009-energies_exc1[-1])}")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Energy from excitation ansatz1 = -9.008866208078738
# Energy difference for ansatz1 = 0.000133791921262727
# --- 215.55524587631226 seconds ---

# %%
#JISP16



import pennylane as qml
from pennylane import numpy as np
import openfermion as of
import matplotlib.pyplot as plt
from openfermion.utils import hermitian_conjugated
import time
start_time = time.time()

s1 = -3.068
s3 =  6.262
s5 = -2.270

# One-body terms
H  = of.ops.FermionOperator("0^ 0", s5)
H += of.ops.FermionOperator("1^ 1", s5)
H += of.ops.FermionOperator("2^ 2", s5)
H += of.ops.FermionOperator("3^ 3", s5)
H += of.ops.FermionOperator("4^ 4", s5)
H += of.ops.FermionOperator("5^ 5", s5)
H += of.ops.FermionOperator("6^ 6", s1)
H += of.ops.FermionOperator("7^ 7", s1)
H += of.ops.FermionOperator("8^ 8", s3)
H += of.ops.FermionOperator("9^ 9", s3)
H += of.ops.FermionOperator("10^ 10", s3)
H += of.ops.FermionOperator("11^ 11", s3)

#Two-body terms

#Diagonal
H += of.ops.FermionOperator("1^ 4^ 4 1", -0.66993)
H += of.ops.FermionOperator("1^ 6^ 6 1", -1.19567)
H += of.ops.FermionOperator("1^ 10^ 10 1", -0.30868)

H += of.ops.FermionOperator("3^ 5^ 5 3", -0.91307)
H += of.ops.FermionOperator("3^ 7^ 7 3", -0.09833)
H += of.ops.FermionOperator("3^ 11^ 11 3", -1.12139)

H += of.ops.FermionOperator("5^ 9^ 9 5", -0.68693)

H += of.ops.FermionOperator("7^ 9^ 9 7", -0.619)

H += of.ops.FermionOperator("9^ 11^ 11 9", -0.247)


#Off-diagonal
#H += of.ops.FermionOperator("^ ^ ", )

H += of.ops.FermionOperator("1^ 4^ 6 1", -0.42552)
H += of.ops.FermionOperator("1^ 6^ 4 1", -0.42552)
H += of.ops.FermionOperator("1^ 4^ 10 1", -0.48672)
H += of.ops.FermionOperator("1^ 10^ 4 1", -0.48672)
H += of.ops.FermionOperator("1^ 4^ 5 3", 0.40776)
H += of.ops.FermionOperator("3^ 5^ 4 1", 0.40776)
H += of.ops.FermionOperator("1^ 4^ 7 3", 0.19030)
H += of.ops.FermionOperator("3^ 7^ 4 1", 0.19030)
H += of.ops.FermionOperator("1^ 4^ 11 3", -0.63519)
H += of.ops.FermionOperator("3^ 11^ 4 1", -0.63519)
H += of.ops.FermionOperator("1^ 4^ 9 5", -0.70362)
H += of.ops.FermionOperator("5^ 9^ 4 1", -0.70362)
H += of.ops.FermionOperator("1^ 4^ 9 7", -0.60060)
H += of.ops.FermionOperator("7^ 9^ 4 1", -0.60060)
H += of.ops.FermionOperator("1^ 4^ 11 9",-0.43626)
H += of.ops.FermionOperator("9^ 11^ 4 1",-0.43626)

H += of.ops.FermionOperator("3^ 11^ 11 9", 0.57586)
H += of.ops.FermionOperator("9^ 11^ 11 3", 0.57586)

H += of.ops.FermionOperator("5^ 9^ 9 7", -0.22527)
H += of.ops.FermionOperator("7^ 9^ 9 5", -0.22527)
H += of.ops.FermionOperator("5^ 9^ 11 9", -0.35264)
H += of.ops.FermionOperator("9^ 11^ 9 5", -0.35264)

H += of.ops.FermionOperator("7^ 9^ 11 9", -0.18400)
H += of.ops.FermionOperator("9^ 11^ 9 7", -0.18400)


exact_gs_energy = of.linalg.eigenspectrum(H)
H_JW = qml.import_operator(of.transforms.jordan_wigner(H), format="openfermion")
dev = qml.device("default.qubit", wires=12)

@qml.qnode(dev)
def excitation_ansatz1(params):
    # Prepare the Hartree-Fock state
    qml.PauliX(wires=1)
    qml.PauliX(wires=4)
    
    # DoubleExcitation: |1, 4> --> |3, 5>; |3, 7>; |3, 11>, |5, 9>, |7, 9>, |9, 11>
    qml.DoubleExcitation(params[0], wires=[1, 4, 3, 5])
    qml.DoubleExcitation(params[1], wires=[1, 4, 3, 7])
    qml.DoubleExcitation(params[2], wires=[1, 4, 3, 11])
    qml.DoubleExcitation(params[3], wires=[1, 4, 5, 9])
    qml.DoubleExcitation(params[4], wires=[1, 4, 7, 9])
    qml.DoubleExcitation(params[5], wires=[1, 4, 9, 11])
    
    # SingleExcitation:   |1, 4> --> |1, 6>; |1, 10>
    qml.SingleExcitation(params[6], wires=[4, 6])
    qml.SingleExcitation(params[7], wires=[4, 10])
    return qml.expval(H_JW)
    

    
N_its = 150
opt_exc1 = qml.GradientDescentOptimizer(stepsize=0.1)
energies_exc1 = []
params_exc1 = np.zeros(8)



for it in range(N_its):
    params_exc1, _cost = opt_exc1.step_and_cost(excitation_ansatz1, params_exc1)
    energies_exc1.append(_cost)
#print(params_exc1)


plt.rcParams["font.size"] = 14
plt.figure(figsize=(10, 6))
plt.plot(energies_exc1, label="Exc. Ansatz 1")
plt.axhline(y=-7.642, color="black", linestyle="dashed", label="Exact value")
plt.xlabel("Gradient descent iterations")
plt.ylabel("Energy")
plt.text(70, -5.5, "JISP16")
plt.text(70, -5.3, r'$^{18}$O (2$^+$)')
plt.legend()
plt.show()

print(f"Energy from excitation ansatz1 = {energies_exc1[-1]}")  
print(f"Energy difference for ansatz1 = {abs(-7.642-energies_exc1[-1])}")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Energy from excitation ansatz1 = -7.641833393332238
# Energy difference for ansatz1 = 0.000166606667762359
# --- 136.55871033668518 seconds ---

# %%
#N3LO



import pennylane as qml
from pennylane import numpy as np
import openfermion as of
import matplotlib.pyplot as plt
from openfermion.utils import hermitian_conjugated
import time
start_time = time.time()

s1 = -3.638
s3 =  3.763
s5 = -3.042

# One-body terms
H  = of.ops.FermionOperator("0^ 0", s5)
H += of.ops.FermionOperator("1^ 1", s5)
H += of.ops.FermionOperator("2^ 2", s5)
H += of.ops.FermionOperator("3^ 3", s5)
H += of.ops.FermionOperator("4^ 4", s5)
H += of.ops.FermionOperator("5^ 5", s5)
H += of.ops.FermionOperator("6^ 6", s1)
H += of.ops.FermionOperator("7^ 7", s1)
H += of.ops.FermionOperator("8^ 8", s3)
H += of.ops.FermionOperator("9^ 9", s3)
H += of.ops.FermionOperator("10^ 10", s3)
H += of.ops.FermionOperator("11^ 11", s3)

#Two-body terms

#Diagonal
H += of.ops.FermionOperator("1^ 4^ 4 1", -0.68643)
H += of.ops.FermionOperator("1^ 6^ 6 1", -1.19633)
H += of.ops.FermionOperator("1^ 10^ 10 1", -0.47381)

H += of.ops.FermionOperator("3^ 5^ 5 3", -0.93957)
H += of.ops.FermionOperator("3^ 7^ 7 3",  -0.24167)
H += of.ops.FermionOperator("3^ 11^ 11 3", -1.23905)

H += of.ops.FermionOperator("5^ 9^ 9 5", -0.84714)

H += of.ops.FermionOperator("7^ 9^ 9 7", -0.663)

H += of.ops.FermionOperator("9^ 11^ 11 9", -0.259)


#Off-diagonal
#H += of.ops.FermionOperator("^ ^ ", )

H += of.ops.FermionOperator("1^ 4^ 6 1", -0.43807)	#
H += of.ops.FermionOperator("1^ 6^ 4 1", -0.43807)	#
H += of.ops.FermionOperator("1^ 4^ 10 1", -0.49395)	#
H += of.ops.FermionOperator("1^ 10^ 4 1", -0.49395)	#
H += of.ops.FermionOperator("1^ 4^ 5 3", 0.42453)	#
H += of.ops.FermionOperator("3^ 5^ 4 1", 0.42453)	#
H += of.ops.FermionOperator("1^ 4^ 7 3", 0.19591)	#
H += of.ops.FermionOperator("3^ 7^ 4 1", 0.19591)	#
H += of.ops.FermionOperator("1^ 4^ 11 3", -0.64104)	#
H += of.ops.FermionOperator("3^ 11^ 4 1", -0.64104)	#
H += of.ops.FermionOperator("1^ 4^ 9 5", -0.71262)	#
H += of.ops.FermionOperator("5^ 9^ 4 1", -0.71262)	#
H += of.ops.FermionOperator("1^ 4^ 9 7", -0.52889)	#
H += of.ops.FermionOperator("7^ 9^ 4 1", -0.52889)	#
H += of.ops.FermionOperator("1^ 4^ 11 9",-0.48586)	#
H += of.ops.FermionOperator("9^ 11^ 4 1",-0.48586)	#

H += of.ops.FermionOperator("1^ 6^ 10 1", -0.21349)	#
H += of.ops.FermionOperator("1^ 10^ 6 1", -0.21349)	#
H += of.ops.FermionOperator("1^ 6^ 5 3", 0.58774)	#
H += of.ops.FermionOperator("3^ 5^ 6 1", 0.58774)	#
H += of.ops.FermionOperator("1^ 6^ 7 3", 0.53367)	#
H += of.ops.FermionOperator("3^ 7^ 6 1", 0.53367)	#
H += of.ops.FermionOperator("1^ 6^ 11 3", 0.15807)	#
H += of.ops.FermionOperator("3^ 11^ 6 1", 0.15807)	#
H += of.ops.FermionOperator("1^ 6^ 9 5", -0.07666)	#
H += of.ops.FermionOperator("5^ 9^ 6 1", -0.07666)	#
H += of.ops.FermionOperator("1^ 6^ 9 7 ", -1.43412)	#
H += of.ops.FermionOperator("7^ 9^ 6 1 ", -1.43412)	#
H += of.ops.FermionOperator("1^ 6^ 11 9", -0.79328)	#
H += of.ops.FermionOperator("9^ 11^ 6 1", -0.79328)	#

H += of.ops.FermionOperator("1^ 10^ 5 3", -0.05919)	#
H += of.ops.FermionOperator("3^ 5^ 10 1", -0.05919)	#
H += of.ops.FermionOperator("1^ 10^ 7 3", 0.02971)	#
H += of.ops.FermionOperator("3^ 7^ 10 1", 0.02971)	#
H += of.ops.FermionOperator("1^ 10^ 11 3", -0.32977)	#
H += of.ops.FermionOperator("3^ 11^ 10 1", -0.32977)	#
H += of.ops.FermionOperator("1^ 10^ 9 5", -0.42931)	#
H += of.ops.FermionOperator("5^ 9^ 10 1", -0.42931)	#
H += of.ops.FermionOperator("1^ 10^ 9 7", -0.47822)	#
H += of.ops.FermionOperator("7^ 9^ 10 1", -0.47822)	#
H += of.ops.FermionOperator("1^ 10^ 11 9", -0.61071)	#
H += of.ops.FermionOperator("9^ 11^ 10 1", -0.61071)	#

H += of.ops.FermionOperator("3^ 5^ 7 3", -0.26284)	#
H += of.ops.FermionOperator("3^ 7^ 5 3", -0.26284)	#
H += of.ops.FermionOperator("3^ 5^ 11 3", -0.75416)	#
H += of.ops.FermionOperator("3^ 11^ 5 3", -0.75416)	#
H += of.ops.FermionOperator("3^ 5^ 9 5 ", -0.36192)	#
H += of.ops.FermionOperator("5^ 9^ 5 3 ", -0.36192)	#
H += of.ops.FermionOperator("3^ 5^ 9 7", 0.70958)	#
H += of.ops.FermionOperator("7^ 9^ 5 3", 0.70958)	#
H += of.ops.FermionOperator("3^ 5^ 11 9", 0.65185)	#
H += of.ops.FermionOperator("9^ 11^ 5 3", 0.65185)	#

H += of.ops.FermionOperator("3^ 7^ 11 3", -0.10010)	#
H += of.ops.FermionOperator("3^ 11^ 7 3", -0.10010)	#
H += of.ops.FermionOperator("3^ 7^ 9 5", 0.10632)	#
H += of.ops.FermionOperator("5^ 9^ 7 3", 0.10632)	#
H += of.ops.FermionOperator("3^ 7^ 9 7", 0.64136)	#
H += of.ops.FermionOperator("7^ 9^ 7 3", 0.64136)	#
H += of.ops.FermionOperator("3^ 7^ 11 9", 0.35477)
H += of.ops.FermionOperator("9^ 11^ 7 3", 0.35477)

H += of.ops.FermionOperator("3^ 11^ 9 5", -0.74523)	#
H += of.ops.FermionOperator("5^ 9^ 11 3", -0.74523)	#
H += of.ops.FermionOperator("3^ 11^ 9 7", 0.42773)	#
H += of.ops.FermionOperator("7^ 9^ 11 3", 0.42773)	#
H += of.ops.FermionOperator("3^ 11^ 11 9", 0.54623)	#
H += of.ops.FermionOperator("9^ 11^ 11 3", 0.54623)	#

H += of.ops.FermionOperator("5^ 9^ 9 7", -0.26193)	#
H += of.ops.FermionOperator("7^ 9^ 9 5", -0.26193)	#
H += of.ops.FermionOperator("5^ 9^ 11 9", -0.33450)	#
H += of.ops.FermionOperator("9^ 11^ 9 5", -0.33450)	#

H += of.ops.FermionOperator("7^ 9^ 11 9", 0.188)	#
H += of.ops.FermionOperator("9^ 11^ 9 7", 0.188)	#


exact_gs_energy = of.linalg.eigenspectrum(H)
H_JW = qml.import_operator(of.transforms.jordan_wigner(H), format="openfermion")
dev = qml.device("default.qubit", wires=12)

@qml.qnode(dev)
def excitation_ansatz1(params):
    # Prepare the Hartree-Fock state
    qml.PauliX(wires=1)
    qml.PauliX(wires=4)
    
    # DoubleExcitation: |1, 4> --> |3, 5>; |3, 7>; |3, 11>, |5, 9>, |7, 9>, |9, 11>
    qml.DoubleExcitation(params[0], wires=[1, 4, 3, 5])
    qml.DoubleExcitation(params[1], wires=[1, 4, 3, 7])
    qml.DoubleExcitation(params[2], wires=[1, 4, 3, 11])
    qml.DoubleExcitation(params[3], wires=[1, 4, 5, 9])
    qml.DoubleExcitation(params[4], wires=[1, 4, 7, 9])
    qml.DoubleExcitation(params[5], wires=[1, 4, 9, 11])
    
    # SingleExcitation:   |1, 4> --> |1, 6>; |1, 10>
    qml.SingleExcitation(params[6], wires=[4, 6])
    qml.SingleExcitation(params[7], wires=[4, 10])
    return qml.expval(H_JW)
    

    
N_its = 150
opt_exc1 = qml.GradientDescentOptimizer(stepsize=0.1)
energies_exc1 = []
params_exc1 = np.zeros(8)



for it in range(N_its):
    params_exc1, _cost = opt_exc1.step_and_cost(excitation_ansatz1, params_exc1)
    energies_exc1.append(_cost)
#print(params_exc1)


plt.rcParams["font.size"] = 14
plt.figure(figsize=(10, 6))
plt.plot(energies_exc1, label="Exc. Ansatz 1")
plt.axhline(y=-9.132, color="black", linestyle="dashed", label="Exact value")
plt.xlabel("Gradient descent iterations")
plt.ylabel("Energy")
plt.text(70, -7.1, r'N$^3$LO')
plt.text(70, -6.9, r'$^{18}$O (2$^+$)')
plt.legend()
plt.show()

print(f"Energy from excitation ansatz1 = {energies_exc1[-1]}")  
print(f"Energy difference for ansatz1 = {abs(-9.132-energies_exc1[-1])}")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Energy from excitation ansatz1 = -9.120239755839917
# Energy difference for ansatz1 = 0.011760244160083033
# --- 114.43627214431763 seconds ---
