# %%
"""
This program converts J-scheme USDB TBME to neutron-neutron (nn) M-scheme TBME  and print in terms qubit number.
The qubits are arranged as follows:

qubit     n     l    2*j        2*jz
_______________________________________________________
0         0     2     5         -5
1         0     2     5         +5      
2         0     2     5         -3             
3         0     2     5         +3        
4         0     2     5         -1            
5         0     2     5         +1           
6         1     0     1         -1        
7         1     0     1         +1              
8         0     2     3         -3           
9         0     2     3         +3            
10        0     2     3         -1            
11        0     2     3         +1     

For different 2*m it will print different sets of TBMEs.
For sd-shell, allowed 2*m values are: 0, +/-2, +/-4, +/-6, +/-8, +/-10

"""

from sympy.physics.quantum.cg import CG
import numpy as np

#18O --> n = 2
n = 2
factor = (18/(16+n))**0.0


"""
2  2  2  2    0  1  -2.65300
2  2  2  2    1  0  -1.09700
2  2  2  2    2  1  -1.16200
2  2  2  2    3  0  -0.71600
2  2  2  2    4  1  -0.23500
2  2  2  2    5  0  -4.48600


"""

mm = input("Enter 2*m:")
m = int(mm)
j1 = 5; j2 = 5; j3 = 5; j4 = 5

t = 1
t1 = 1; t2 = 1  #p --> tz = -1 (-1/2); n --> tz = 1 (1/2)
t3 = 1; t4 = 1  #p --> tz = -1 (-1/2); n --> tz = 1 (1/2)


# <5/2 5/2 | V | 5/2 5/2>    
if j1 == 5 and j2 == 5 and j3 == 5 and j4 == 5:
    V = np.array([-2.65300, -1.09700, -1.16200, -0.71600, -0.23500, -4.48600 ])
    J = np.array([0, 1, 2, 3, 4, 5])
    T = np.array([1, 0, 1, 0, 1, 0])
    C = 2    
    #print("m-scheme tbme for <5/2 5/2 | V | 5/2 5/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    #print(mm)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3 
                        elif m1 == 5:
                            m11 = 1
                        
                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1
                        
                        #define qubit for m3
                        if m3 == -5:
                            m33 = 0
                        elif m3 == -3:
                            m33 = 2
                        elif m3 == -1:
                            m33 = 4
                        elif m3 == 1:
                            m33 = 5
                        elif m3 == 3:
                            m33 = 3
                        elif m3 == 5:
                            m33 = 1
                            
                        #define qubit for m4
                        if m4 == -5:
                            m44 = 0
                        elif m4 == -3:
                            m44 = 2
                        elif m4 == -1:
                            m44 = 4
                        elif m4 == 1:
                            m44 = 5
                        elif m4 == 3:
                            m44 = 3
                        elif m4 == 5:
                            m44 = 1    
                        print(m11, m22, m33, m44, float(tbme))
                      

"""
2=d5/2;  3=s1/2

2  2  3  3    1  0  -1.22100 
2  2  3  3    0  1  -1.45300

"""

j1 = 5; j2 = 5; j3 = 1; j4 = 1
    
# <5/2 5/2 | V | 1/2 1/2>    
if j1 == 5 and j2 == 5 and j3 == 1 and j4 == 1:
    V = np.array([-1.22100 , -1.45300 ])
    J = np.array([1, 0])
    T = np.array([0, 1])
    C = 2    
    #print("m-scheme tbme for <5/2 5/2 | V | 1/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3 
                        elif m1 == 5:
                            m11 = 1
                        
                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1
                        
                        #define qubit for m3
                        if m3 == -1:
                            m33 = 6
                        elif m3 == 1:
                            m33 = 7
                        
                            
                        #define qubit for m4
                        if m4 == -1:
                            m44 = 6
                        elif m4 == 1:
                            m44 = 7  
                        print(m11, m22, m33, m44, float(tbme))
                    

"""
2=d5/2;  3=s1/2


2  3  2  3    2  0  -0.54500
2  3  2  3    2  1  -1.37500
2  3  2  3    3  0  -3.98400
2  3  2  3    3  1   0.40800

"""

j1 = 5; j2 = 1; j3 = 5; j4 = 1
    
# <5/2 1/2 | V | 5/2 1/2>    
if j1 == 5 and j2 == 1 and j3 == 5 and j4 == 1:
    V = np.array([-0.54500, -1.37500, -3.98400, 0.40800])
    J = np.array([2, 2, 3, 3])
    T = np.array([0, 1, 0, 1])
    C = 1    
    #print("m-scheme tbme for <5/2 1/2 | V | 5/2 1/2>")

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                       
                    
                    #define qubit for m1
                    if m1 == -5:
                        m11 = 0
                    elif m1 == -3:
                        m11 = 2
                    elif m1 == -1:
                        m11 = 4
                    elif m1 == 1:
                        m11 = 5
                    elif m1 == 3:
                        m11 = 3 
                    elif m1 == 5:
                        m11 = 1
                        
                    #define qubit for m2
                    if m2 == -1:
                        m22 = 6
                    elif m2 == 1:
                        m22 = 7
                        
                        
                    #define qubit for m3
                    if m3 == -5:
                        m33 = 0
                    elif m3 == -3:
                        m33 = 2
                    elif m3 == -1:
                        m33 = 4
                    elif m3 == 1:
                        m33 = 5
                    elif m3 == 3:
                        m33 = 3
                    elif m3 == 5:
                        m33 = 1    
                            
                    #define qubit for m4
                    if m4 == -1:
                        m44 = 6
                    elif m4 == 1:
                        m44 = 7  
                    print(m11, m22, m33, m44, float(tbme))

"""
2=d5/2;  3=s1/2

3  3  3  3    0  1  -2.01700
3  3  3  3    1  0  -2.93800

"""

j1 = 1; j2 = 1; j3 = 1; j4 = 1
    
# <1/2 1/2 | V | 1/2 1/2>    
if j1 == 1 and j2 == 1 and j3 == 1 and j4 == 1:
    V = np.array([-2.01700, -2.93800])
    J = np.array([0, 1])
    T = np.array([1, 0])
    C = 2    
    #print("m-scheme tbme for <1/2 1/2 | V | 1/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -1:
                            m11 = 6
                        elif m1 == 1:
                            m11 = 7
                        
                        #define qubit for m2
                        if m2 == -1:
                            m22 = 6
                        elif m2 == 1:
                            m22 = 7
                        
                        
                        #define qubit for m3
                        if m3 == -1:
                            m33 = 6
                        elif m3 == 1:
                            m33 = 7
                        
                            
                        #define qubit for m4
                        if m4 == -1:
                            m44 = 6
                        elif m4 == 1:
                            m44 = 7  
                        print(m11, m22, m33, m44, float(tbme))
                        

"""
 2  2  1  1    0  1  -2.24000
 2  2  1  1    1  0   2.47500
 2  2  1  1    2  1  -0.77100
 2  2  1  1    3  0   0.93800
"""
j1 = 5; j2 = 5; j3 = 3; j4 = 3



# <3/2 3/2 | V | 5/2 5/2>
if j1 == 5 and j2 == 5 and j3 == 3 and j4 == 3:
    V = np.array([-2.24000, 2.47500, -0.77100, 0.93800])
    J = np.array([0, 1, 2, 3])
    T = np.array([1, 0, 1, 0])
    C =  2
    #print("m-scheme tbme for <5/2 5/2 | V | 3/2 3/2>")

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:

                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()

                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])

                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -5:
                            m11 = 0
                        elif m1 == -3:
                            m11 = 2
                        elif m1 == -1:
                            m11 = 4
                        elif m1 == 1:
                            m11 = 5
                        elif m1 == 3:
                            m11 = 3
                        elif m1 == 5:
                            m11 = 1

                        #define qubit for m2
                        if m2 == -5:
                            m22 = 0
                        elif m2 == -3:
                            m22 = 2
                        elif m2 == -1:
                            m22 = 4
                        elif m2 == 1:
                            m22 = 5
                        elif m2 == 3:
                            m22 = 3
                        elif m2 == 5:
                            m22 = 1

                        #define qubit for m3
                        #if m3 == -5:
                        #    m33 = 7
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9
                        #elif m3 == 5:
                        #    m33 = 12

                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))

"""
2  1  2  1    1  0  -5.7120
2  1  2  1    2  0  -3.4010
2  1  2  1    3  0  -0.6540
2  1  2  1    4  0  -4.2670
2  1  2  1    1  1   0.03200
2  1  2  1    2  1  -0.13600
2  1  2  1    3  1   0.15300
2  1  2  1    4  1  -1.3410

"""

j1 = 5; j2 = 3; j3 = 5; j4 = 3
    
# <5/2 3/2 | V | 5/2 3/2>    
if j1 == 5 and j2 == 3 and j3 == 5 and j4 == 3:
    V = np.array([-5.7120, -3.4010, -0.6540, -4.2670, 0.03200, -0.13600, 0.15300, -1.64100 ])
    J = np.array([1, 2, 3, 4, 1, 2, 3, 4 ])
    T = np.array([0, 0, 0, 0, 1, 1, 1, 1])
    C =  1 
    #print("m-scheme tbme for <5/2 3/2 | V | 5/2 3/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                       
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    #if m1 < m2 and m3 < m4:
                    #define qubit for m1
                    if m1 == -5:
                        m11 = 0
                    elif m1 == -3:
                        m11 = 2
                    elif m1 == -1:
                        m11 = 4
                    elif m1 == 1:
                        m11 = 5
                    elif m1 == 3:
                        m11 = 3
                    elif m1 == 5:
                        m11 = 1
                        
                    #define qubit for m2
                    if m2 == -3:
                        m22 = 8
                    elif m2 == -1:
                        m22 = 10
                    elif m2 == 1:
                        m22 = 11
                    elif m2 == 3:
                        m22 = 9
                        
                    #define qubit for m3
                    if m3 == -5:
                        m33 = 0
                    if m3 == -3:
                        m33 = 2
                    elif m3 == -1:
                        m33 = 4
                    elif m3 == 1:
                        m33 = 5
                    elif m3 == 3:
                        m33 = 3
                    elif m3 == 5:
                        m33 = 1        
                            
                    #define qubit for m4
                    if m4 == -3:
                        m44 = 8
                    elif m4 == -1:
                        m44 = 10
                    elif m4 == 1:
                        m44 = 11
                    elif m4 == 3:
                        m44 = 9
                    print(m11, m22, m33, m44, float(tbme))                        

"""
1=d3/2

1  1  1  1    0  1  -1.3380
1  1  1  1    1  0  -1.4510
1  1  1  1    2  1  -0.2250
1  1  1  1    3  0  -3.1990


"""

j1 = 3; j2 = 3; j3 = 3; j4 = 3
    
# <3/2 3/2 | V | 3/2 3/2>    
if j1 == 3 and j2 == 3 and j3 == 3 and j4 == 3:
    V = np.array([-1.3380, -1.4510, -0.2250, -3.1990])
    J = np.array([0, 1, 2, 3 ])
    T = np.array([1, 0, 1, 0])
    C = 2 
    #print("m-scheme tbme for <3/2 3/2 | V | 3/2 3/2>")

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                       
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -3:
                            m11 = 8
                        elif m1 == -1:
                            m11 = 10
                        elif m1 == 1:
                            m11 = 11
                        elif m1 == 3:
                            m11 = 9
                        
                        #define qubit for m2
                        if m2 == -3:
                            m22 = 8
                        elif m2 == -1:
                            m22 = 10
                        elif m2 == 1:
                            m22 = 11
                        elif m2 == 3:
                            m22 = 9
                        
                        #define qubit for m3
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9       
                            
                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))                        

"""
1=d3/2   3=1s1/2

1  1  3  3    0  1  -0.6310
1  1  3  3    1  0   0.7520

"""

j1 = 1; j2 = 1; j3 = 3; j4 = 3
    
# <3/2 3/2 | V | 1/2 1/2>    
if j1 == 1 and j2 == 1 and j3 == 3 and j4 == 3:
    V = np.array([-0.6310, 0.7520])
    J = np.array([ 0, 1])
    T = np.array([ 1, 0])
    C = 2 
    #print("m-scheme tbme for <3/2 3/2 | V | 1/2 1/2>")

for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    if m1 < m2 and m3 < m4:
                        #define qubit for m1
                        if m1 == -1:
                            m11 = 6
                        elif m1 == 1:
                            m11 = 7
                        
                        #define qubit for m2
                        if m2 == -1:
                            m22 = 6
                        elif m2 == 1:
                            m22 = 7
                        
                        
                        #define qubit for m3
                        if m3 == -3:
                            m33 = 8
                        elif m3 == -1:
                            m33 = 10
                        elif m3 == 1:
                            m33 = 11
                        elif m3 == 3:
                            m33 = 9       
                            
                        #define qubit for m4
                        if m4 == -3:
                            m44 = 8
                        elif m4 == -1:
                            m44 = 10
                        elif m4 == 1:
                            m44 = 11
                        elif m4 == 3:
                            m44 = 9
                        print(m11, m22, m33, m44, float(tbme))                        

"""
1=d3/2   3=1s1/2

1  3  1  3    1  0  -3.6200
1  3  1  3    1  1   0.11100 
1  3  1  3    2  0  -1.8820
1  3  1  3    2  1  -0.5180

"""

j1 = 1; j2 = 3; j3 = 1; j4 = 3
    
# <3/2 1/2 | V | 3/2 1/2>    
if j1 == 1 and j2 == 3 and j3 == 1 and j4 == 3:
    V = np.array([-3.6200, 0.11100 , -1.8820, -0.5180])
    J = np.array([ 1, 1, 2, 2])
    T = np.array([ 0, 1, 0, 1])
    C = 1 
    #print("m-scheme tbme for <3/2 1/2 | V | 3/2 1/2>")
    
for m1 in range(-j1, j1+2, 2):
    for m2 in range(-j2, j2+2, 2):
        for m3 in range(-j3, j3+2, 2):
            for m4 in range (-j4, j4+2, 2):
                if m1+ m2 == m3 + m4 == m:
                    
                    #rint(m1, m2, m3, m4)
                    tbme = 0
                    for i in range(len(V)):
                        
                        cg1 = CG(j1/2, m1/2, j2/2, m2/2, J[i], m/2)
                        cg1 = cg1.doit()
                        cg2 = CG(j3/2, m3/2, j4/2, m4/2, J[i], m/2)
                        cg2 = cg2.doit()
                    
                        cg11 = CG(t/2, t1/2, t/2, t2/2, T[i], (t1+t2)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg11 = cg11.doit()
                        cg22 = CG(t/2, t3/2, t/2, t4/2, T[i], (t3+t4)/2)  #pn, tz_p = -1/2, tz_n = 1/2
                        cg22 = cg22.doit()
                        tbme = tbme + C*cg1*cg11*cg2*cg22*V[i]*factor
                        #print(m1, m2, m3, m4, cg1, cg2, V[i])
                        
                    
                    #define qubit for m1
                    if m1 == -1:
                        m11 = 6
                    elif m1 == 1:
                        m11 = 7
                        
                    #define qubit for m2
                    if m2 == -3:
                        m22 = 8
                    elif m2 == -1:
                        m22 = 10
                    elif m2 == 1:
                        m22 = 11
                    elif m2 == 3:
                        m22 = 9
                    
                    #define qubit for m3
                    if m3 == -1:
                        m33 = 6
                    elif m3 == 1:
                        m33 = 7     
                            
                    #define qubit for m4
                    if m4 == -3:
                        m44 = 8
                    elif m4 == -1:
                        m44 = 10
                    elif m4 == 1:
                        m44 = 11
                    elif m4 == 3:
                        m44 = 9
                    print(m11, m22, m33, m44, float(tbme))
# Out:
# Enter 2*m:0
# 0 1 0 1 -1.5927857142857142
# 0 1 2 3 0.6956428571428571
# 0 1 4 5 -0.36457142857142866
# 2 3 0 1 0.6956428571428571
# 2 3 2 3 -1.0630714285714284
# 2 3 4 5 0.8942857142857142
# 4 5 0 1 -0.36457142857142866
# 4 5 2 3 0.8942857142857142
# 4 5 4 5 -1.3941428571428571
# 0 1 6 7 -0.8388899411325262
# 2 3 6 7 0.8388899411325262
# 4 5 6 7 -0.8388899411325262
# 4 7 4 7 -0.48350000000000004
# 4 7 5 6 0.8915
# 5 6 4 7 0.8915
# 5 6 5 6 -0.48350000000000004
# 6 7 6 7 -2.017
# 0 1 8 9 -1.3350911540689285
# 0 1 10 11 0.49386118720917793
# 2 3 8 9 0.8303531739530782
# 2 3 10 11 -0.9985991673250283
# 4 5 8 9 -0.5779841838951529
# 4 5 10 11 1.2509681573829534
# 2 9 2 9 -0.1232
# 2 9 4 11 -0.2336813214615152
# 2 9 5 10 -0.2929589732368681
# 2 9 3 8 -0.2278
# 4 11 2 9 -0.2336813214615152
# 4 11 4 11 -0.6728000000000001
# 4 11 5 10 -0.7532
# 4 11 3 8 -0.2929589732368681
# 5 10 2 9 -0.2929589732368681
# 5 10 4 11 -0.7532
# 5 10 5 10 -0.6728000000000001
# 5 10 3 8 -0.2336813214615152
# 3 8 2 9 -0.2278
# 3 8 4 11 -0.2929589732368681
# 3 8 5 10 -0.2336813214615152
# 3 8 3 8 -0.1232
# 8 9 8 9 -0.7815000000000001
# 8 9 10 11 0.5565
# 10 11 8 9 0.5565
# 10 11 10 11 -0.7815000000000001
# 6 7 8 9 -0.4461843789287115
# 6 7 10 11 0.4461843789287115
# 6 11 6 11 -0.20350000000000001
# 6 11 7 10 -0.3145
# 7 10 6 11 -0.3145
# 7 10 7 10 -0.20350000000000001
